  [ 0.9866666666666667, 0.9466666666666667, 0.9266666666666666 ],
  [ 0.9733333333333334, 0.9333333333333333, 0.9533333333333334 ],
  [ 0.98, 0.9266666666666666, 0.94 ],
  [ 0.98, 0.9533333333333334, 0.96 ],
  [ 0.98, 0.9533333333333334, 0.94 ],
  [ 0.9666666666666667, 0.9666666666666667, 0.96 ],
  [ 0.96, 0.96, 0.9466666666666667 ],
  [ 0.98, 0.9666666666666667, 0.96 ],
  [ 0.98, 0.9733333333333334, 0.9533333333333334 ],
  [ 0.98, 0.96, 0.94 ],
  [ 0.9733333333333334, 0.9733333333333334, 0.94 ],
  [ 0.9733333333333334, 0.9533333333333334, 0.94 ]
]

n_10_e_diff_acc = [
  [ 0.17333333333333334, 0.28, 0.30666666666666664 ],
  [ 0.26, 0.23333333333333334, 0.8 ],
  [ 0.17333333333333334, 0.32, 0.8666666666666667 ],
  [ 0.32, 0.26666666666666666, 0.8933333333333333 ],
  [ 0.3933333333333333, 0.25333333333333335, 0.9266666666666666 ],
  [ 0.26, 0.2866666666666667, 0.94 ],
  [ 0.26666666666666666, 0.24666666666666667, 0.2866666666666667 ],
  [ 0.29333333333333333, 0.28, 0.28 ],
  [ 0.26, 0.24666666666666667, 0.66 ],
  [ 0.12666666666666668, 0.12666666666666668, 0.8866666666666667 ],
  [ 0.2, 0.2866666666666667, 0.9333333333333333 ],
  [ 0.30666666666666664, 0.36, 0.94 ],
  [ 0.2866666666666667, 0.30666666666666664, 0.94 ],
  [ 0.3333333333333333, 0.2866666666666667, 0.2866666666666667 ],
  [ 0.32, 0.24666666666666667, 0.38 ],
  [ 0.26, 0.26666666666666666, 0.88 ],
  [ 0.36, 0.21333333333333335, 0.9133333333333333 ],
  [ 0.17333333333333334, 0.2, 0.9133333333333333 ],
  [ 0.14666666666666667, 0.36, 0.94 ],
  [ 0.18666666666666668, 0.2733333333333333, 0.17333333333333334 ],
  [ 0.34, 0.26, 0.4666666666666667 ],
  [ 0.42, 0.44, 0.8133333333333334 ],
  [ 0.16, 0.12666666666666668, 0.92 ],
  [ 0.13333333333333333, 0.12666666666666668, 0.9266666666666666 ],
  [ 0.38, 0.36666666666666664, 0.96 ]
]

n_10_e_8_acc_client = [[], [], []]

n_10_e_1_acc_client = [[], [], []]

n_10_e_15_acc_client = [[], [], []]

n_10_e_4_acc_client = [[], [], []]

n_10_e_40_acc_client1 = []
n_10_e_40_acc_client2 = []
n_10_e_40_acc_client3 = []

n_10_e_diff_acc_client1 = []
n_10_e_diff_acc_client2 = []
n_10_e_diff_acc_client3 = []


for i in n_10_e_8_acc:
    for j in range(3):
        n_10_e_8_acc_client[j].append(i[j]*100)

for i in n_10_e_1_acc:
    for j in range(3):
        n_10_e_1_acc_client[j].append(i[j]*100)

for i in n_10_e_15_acc:
    for j in range(3):
        n_10_e_15_acc_client[j].append(i[j]*100)

for i in n_10_e_4_acc:
    for j in range(3):
        n_10_e_4_acc_client[j].append(i[j]*100)

for i in n_10_e_40_acc:
    n_10_e_40_acc_client1.append(i[0]*100)
    n_10_e_40_acc_client2.append(i[1]*100)
    n_10_e_40_acc_client3.append(i[2]*100)

for i in n_10_e_diff_acc:
    n_10_e_diff_acc_client1.append(i[0]*100)
    n_10_e_diff_acc_client2.append(i[1]*100)
    n_10_e_diff_acc_client3.append(i[2]*100)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import figure

for i in range(3):
    plt.clf()
    plt.plot(rounds, n_10_e_1_acc_client[i], label='E = 1')
    plt.plot(rounds, n_10_e_4_acc_client[i], label='E = 4')
    plt.plot(rounds, n_10_e_8_acc_client[i], label='E = 8')
    plt.plot(rounds, n_10_e_15_acc_client[i], label='E = 15')
    plt.legend()
    plt.xlabel('Federated Learning Rounds')
    plt.ylabel('Accuracy (%)')
    
    plt.savefig('./results/client{}_10_epochs_75_images_vary_epsilon.png'.format(i+1))

# %% [markdown]
# ## Epochs: 5

# %%
### Epochs: 5
n_5_e_8_acc = [
  [ 0.25333333333333335, 0.23333333333333334, 0.24 ],
  [ 0.6066666666666667, 0.6266666666666667, 0.6 ],
  [ 0.5133333333333333, 0.4533333333333333, 0.5333333333333333 ],
  [ 0.86, 0.82, 0.86 ],
  [ 0.84, 0.8133333333333334, 0.8666666666666667 ],
  [ 0.9066666666666666, 0.8866666666666667, 0.94 ],
  [ 0.9266666666666666, 0.9, 0.94 ],
  [ 0.9466666666666667, 0.94, 0.9733333333333334 ],
  [ 0.96, 0.9266666666666666, 0.9733333333333334 ],
  [ 0.96, 0.9466666666666667, 0.9533333333333334 ],
  [ 0.9866666666666667, 0.96, 0.9466666666666667 ],
  [ 0.9933333333333333, 0.96, 0.9533333333333334 ],
  [ 0.98, 0.9466666666666667, 0.9533333333333334 ],
  [ 0.98, 0.9733333333333334, 0.9733333333333334 ],
  [ 0.98, 0.9533333333333334, 0.96 ],
  [ 0.96, 0.9466666666666667, 0.9533333333333334 ],
  [ 0.9866666666666667, 0.9466666666666667, 0.9666666666666667 ],
  [ 0.9733333333333334, 0.9466666666666667, 0.94 ],
  [ 0.9866666666666667, 0.9733333333333334, 0.9533333333333334 ],
  [ 0.96, 0.9466666666666667, 0.9466666666666667 ],
  [ 0.98, 0.94, 0.9466666666666667 ],
  [ 0.98, 0.96, 0.96 ],
  [ 0.9733333333333334, 0.96, 0.9533333333333334 ],
  [ 0.9733333333333334, 0.96, 0.96 ],
  [ 0.98, 0.9666666666666667, 0.96 ]
]

n_5_e_15_acc=[
  [ 0.19333333333333333, 0.18666666666666668, 0.16666666666666666 ],
  [ 0.52, 0.46, 0.46 ],
  [ 0.8133333333333334, 0.8266666666666667, 0.84 ],
  [ 0.7866666666666666, 0.7466666666666667, 0.8 ],
  [ 0.9066666666666666, 0.8666666666666667, 0.9066666666666666 ],
  [ 0.9266666666666666, 0.8733333333333333, 0.9 ],
  [ 0.9333333333333333, 0.8933333333333333, 0.9066666666666666 ],
  [ 0.94, 0.9066666666666666, 0.92 ],
  [ 0.9533333333333334, 0.9266666666666666, 0.92 ],
  [ 0.09333333333333334, 0.1, 0.1 ],
  [ 0.15333333333333332, 0.10666666666666667, 0.15333333333333332 ],
  [ 0.12666666666666668, 0.18, 0.13333333333333333 ],
  [ 0.16, 0.16666666666666666, 0.12666666666666668 ],
  [ 0.09333333333333334, 0.16, 0.08 ],
  [ 0.14, 0.16, 0.14666666666666667 ],
  [ 0.12666666666666668, 0.11333333333333333, 0.10666666666666667 ],
  [ 0.12666666666666668, 0.12666666666666668, 0.12 ],
  [ 0.14666666666666667, 0.16, 0.14666666666666667 ],
  [ 0.14, 0.12, 0.11333333333333333 ],
  [ 0.1, 0.09333333333333334, 0.12 ],
  [ 0.17333333333333334, 0.15333333333333332, 0.08 ],
  [ 0.07333333333333333, 0.12, 0.12666666666666668 ],
  [ 0.11333333333333333, 0.17333333333333334, 0.12 ],
  [ 0.12666666666666668, 0.10666666666666667, 0.12666666666666668 ],
  [ 0.11333333333333333, 0.12, 0.12 ],
  [ 0.06, 0.14666666666666667, 0.10666666666666667 ],
  [ 0.12, 0.1, 0.10666666666666667 ]
]

n_5_e_8_acc_client = [[], [], []]

n_5_e_15_acc_client = [[], [], []]

n_5_e_4_acc_client = [[], [], []]

n_5_e_1_acc_client = [[], [], []]


for i in n_5_e_8_acc:
    for j in range(3):
        n_5_e_8_acc_client[j].append(i[j]*100)


for i in n_5_e_15_acc:
    for j in range(3):
        n_5_e_15_acc_client[j].append(i[j]*100)

for i in n_5_e_4_acc:
    for j in range(3):
        n_5_e_4_acc_client[j].append(i[j]*100)

for i in n_5_e_1_acc:
    for j in range(3):
        n_5_e_1_acc_client[j].append(i[j]*100)

import matplotlib.pyplot as plt
import numpy as np

for i in range(3):
    plt.clf()
    plt.plot(rounds, n_5_e_1_acc_client[i], label='E = 1')
    plt.plot(rounds, n_5_e_4_acc_client[i], label='E = 4')
    plt.plot(rounds, n_5_e_8_acc_client[i], label='E = 8')
    plt.plot(rounds, n_5_e_15_acc_client[i], label='E = 15')
    plt.legend()
    plt.xlabel('Federated Learning Rounds')
    plt.ylabel('Accuracy (%)')
    
    plt.savefig('./results/client{}_5_epochs_75_images_vary_epsilon.png'.format(i+1))

# %%
# epoches: 10, epsilon: 8
n_10_e_8_i_15_acc = [
  [ 0.11333333333333333, 0.12666666666666668, 0.11333333333333333 ],
  [ 0.34, 0.38666666666666666, 0.43333333333333335 ],
  [ 0.3466666666666667, 0.42, 0.4066666666666667 ],
  [ 0.52, 0.66, 0.64 ],
  [ 0.56, 0.7066666666666667, 0.7266666666666667 ],
  [ 0.72, 0.76, 0.8 ],
  [ 0.7533333333333333, 0.84, 0.8266666666666667 ],
  [ 0.76, 0.7866666666666666, 0.7666666666666667 ],
  [ 0.76, 0.8466666666666667, 0.8466666666666667 ],
  [ 0.8066666666666666, 0.8933333333333333, 0.8866666666666667 ],
  [ 0.7933333333333333, 0.9, 0.86 ],
  [ 0.8466666666666667, 0.8933333333333333, 0.8533333333333334 ],
  [ 0.981, 0.976, 0.99 ],  [ 0.987, 0.972, 0.988 ],
  [ 0.981, 0.973, 0.984 ], [ 0.981, 0.976, 0.988 ],
  [ 0.977, 0.976, 0.988 ]
]

n_10_e_8_i_200_acc_client = [[], [], []]

n_10_e_8_i_15_acc_client = [[], [], []]

n_10_e_8_i_500_acc_client = [[], [], []]

for i in n_10_e_8_i_15_acc:
    for j in range(3):
        n_10_e_8_i_15_acc_client[j].append(i[j]*100)

for i in n_10_e_8_i_200_acc:
    for j in range(3):
        n_10_e_8_i_200_acc_client[j].append(i[j]*100)       

for i in n_10_e_8_i_500_acc:
    for j in range(3):
        n_10_e_8_i_500_acc_client[j].append(i[j]*100)

import matplotlib.pyplot as plt
import numpy as np

for i in range(3):
    plt.clf()
    plt.plot(rounds, n_10_e_8_i_15_acc_client[i], label='Samples 15')
    plt.plot(rounds, n_10_e_8_acc_client[i], label='Samples 75')
    plt.plot(rounds, n_10_e_8_i_200_acc_client[i], label='Samples 200')
    plt.plot(rounds, n_10_e_8_i_500_acc_client[i], label='Samples 500')
    plt.legend()
    plt.xlabel('Federated Learning Rounds')
    plt.ylabel('Accuracy (%)')
    
    plt.savefig('./results/client{}_10_epochs_8_epsilon_vary_datasize.png'.format(i+1))

# %%
# epoches: 1, images_per_digit: 15, epsilon: 8

n_1_e_8_i_15_acc = [
  [ 0.1, 0.1, 0.1 ],
  [ 0.17333333333333334, 0.17333333333333334, 0.18 ],
  [ 0.14, 0.14666666666666667, 0.16666666666666666 ],
  [ 0.11333333333333333, 0.11333333333333333, 0.14 ],
  [ 0.2, 0.17333333333333334, 0.22666666666666666 ],
  [ 0.25333333333333335, 0.36, 0.3466666666666667 ],
  [ 0.2733333333333333, 0.25333333333333335, 0.32666666666666666 ],
  [ 0.24666666666666667, 0.3466666666666667, 0.29333333333333333 ],
  [ 0.38, 0.36666666666666664, 0.4 ],
  [ 0.5066666666666667, 0.56, 0.58 ],
  [ 0.56, 0.62, 0.6066666666666667 ],
  [ 0.58, 0.7333333333333333, 0.66 ],
  [ 0.6266666666666667, 0.7066666666666667, 0.6266666666666667 ],
  [ 0.6666666666666666, 0.7733333333333333, 0.6933333333333334 ],
  [ 0.6666666666666666, 0.72, 0.7266666666666667 ],
  [ 0.7, 0.7866666666666666, 0.72 ],
  [ 0.7266666666666667, 0.74, 0.7266666666666667 ],
  [ 0.7133333333333334, 0.7733333333333333, 0.76 ],
  [ 0.7466666666666667, 0.8066666666666666, 0.7266666666666667 ],
  [ 0.7333333333333333, 0.86, 0.7466666666666667 ],
  [ 0.74, 0.8, 0.7733333333333333 ],
  [ 0.7266666666666667, 0.8666666666666667, 0.8 ],
  [ 0.7533333333333333, 0.8266666666666667, 0.8 ],
  [ 0.78, 0.8733333333333333, 0.7933333333333333 ],
  [ 0.7933333333333333, 0.8666666666666667, 0.7733333333333333 ]
]

n_1_e_15_i_15_acc = [
  [ 0.12666666666666668, 0.12, 0.16666666666666666 ],
  [ 0.12666666666666668, 0.13333333333333333, 0.15333333333333332 ]
]

# %%
n_15_e_vary_i_75_acc = [
  [ 0.15333333333333332, 0.16, 0.14 ],
  [ 0.5066666666666667, 0.5333333333333333, 0.5466666666666666 ],
  [ 0.8866666666666667, 0.8733333333333333, 0.88 ],
  [ 0.9133333333333333, 0.8533333333333334, 0.8933333333333333 ],
  [ 0.96, 0.9, 0.9333333333333333 ],
  [ 0.9533333333333334, 0.8866666666666667, 0.9266666666666666 ],
  [ 0.9333333333333333, 0.92, 0.92 ],
  [ 0.98, 0.9333333333333333, 0.9466666666666667 ],
  [ 0.9866666666666667, 0.94, 0.9466666666666667 ],
  [ 0.9733333333333334, 0.9466666666666667, 0.9333333333333333 ],
  [ 0.9666666666666667, 0.9466666666666667, 0.94 ],
  [ 0.96, 0.9466666666666667, 0.96 ],
  [ 0.98, 0.96, 0.96 ],
  [ 0.9866666666666667, 0.9666666666666667, 0.9666666666666667 ],
  [ 0.9733333333333334, 0.94, 0.96 ],
  [ 0.98, 0.96, 0.9533333333333334 ],
  [ 0.98, 0.94, 0.9533333333333334 ],
  [ 0.98, 0.96, 0.9666666666666667 ],
  [ 0.9733333333333334, 0.9533333333333334, 0.9666666666666667 ],
  [ 0.9866666666666667, 0.9466666666666667, 0.9666666666666667 ],
  [ 0.9933333333333333, 0.96, 0.9733333333333334 ],
  [ 0.98, 0.94, 0.98 ],
  [ 0.9933333333333333, 0.9466666666666667, 0.98 ],
  [ 0.98, 0.9533333333333334, 0.98 ],
  [ 1, 0.9466666666666667, 0.9733333333333334 ]
]

n_15_e_vary_i_75_acc_client = [[], [], []]

for i in n_15_e_vary_i_75_acc:
    for j in range(3):
        n_15_e_vary_i_75_acc_client[j].append(i[j]*100)

import matplotlib.pyplot as plt
import numpy as np

plt.plot(rounds, n_15_e_vary_i_75_acc_client[0], label='Client 1, E = 8')
plt.plot(rounds, n_15_e_vary_i_75_acc_client[1], label='Client 2, E = 10')
plt.plot(rounds, n_15_e_vary_i_75_acc_client[2], label='Client 3, E = 12')
plt.legend()
plt.xlabel('Federated Learning Rounds')
plt.ylabel('Accuracy (%)')


plt.savefig('./results/clients_10_epochs_diff_epsilon.png')

# %%
n_15_e_vary2_i_75_acc = [
  [ 0.17333333333333334, 0.14, 0.18 ],
  [ 0.6933333333333334, 0.7333333333333333, 0.6666666666666666 ],
  [ 0.8, 0.8133333333333334, 0.78 ],
  [ 0.8266666666666667, 0.8266666666666667, 0.84 ],
  [ 0.9333333333333333, 0.9266666666666666, 0.9066666666666666 ],
  [ 0.96, 0.9266666666666666, 0.96 ],
  [ 0.94, 0.9333333333333333, 0.92 ],
  [ 0.9533333333333334, 0.94, 0.9466666666666667 ],
  [ 0.96, 0.9333333333333333, 0.9466666666666667 ],
  [ 0.9733333333333334, 0.9333333333333333, 0.92 ],
  [ 0.98, 0.9666666666666667, 0.9333333333333333 ],
  [ 0.9733333333333334, 0.9666666666666667, 0.9666666666666667 ],
  [ 0.9533333333333334, 0.9666666666666667, 0.96 ],
  [ 0.94, 0.94, 0.9466666666666667 ],
  [ 0.96, 0.9533333333333334, 0.9666666666666667 ],
  [ 0.9666666666666667, 0.9533333333333334, 0.96 ],
  [ 0.9533333333333334, 0.94, 0.9466666666666667 ],
  [ 0.9666666666666667, 0.9333333333333333, 0.9466666666666667 ],
  [ 0.98, 0.94, 0.96 ],
  [ 0.9666666666666667, 0.9666666666666667, 0.96 ],
  [ 0.96, 0.9466666666666667, 0.9666666666666667 ],
  [ 0.98, 0.96, 0.9466666666666667 ],
  [ 0.9666666666666667, 0.9466666666666667, 0.96 ],
  [ 0.98, 0.96, 0.96 ],
  [ 0.9666666666666667, 0.9333333333333333, 0.9466666666666667 ]
]

n_15_e_vary2_i_75_acc_client1 = []
n_15_e_vary2_i_75_acc_client2 = []
n_15_e_vary2_i_75_acc_client3 = []

for i in n_15_e_vary2_i_75_acc:
    n_15_e_vary2_i_75_acc_client1.append(i[0]*100)
    n_15_e_vary2_i_75_acc_client2.append(i[1]*100)
    n_15_e_vary2_i_75_acc_client3.append(i[2]*100)

import matplotlib.pyplot as plt
# from matplotlib.pyplot import figure
import numpy as np

# figure(figsize=(8, 6), dpi=80)

plt.plot(rounds, n_15_e_vary2_i_75_acc_client1, label='Client 1, E = 5')
plt.plot(rounds, n_15_e_vary2_i_75_acc_client2, label='Client 2, E = 10')
plt.plot(rounds, n_15_e_vary2_i_75_acc_client3, label='Client 3, E = 15')
plt.legend()
plt.xlabel('Federated Learning Rounds')
plt.ylabel('Accuracy (%)')

plt.savefig('./results/clients_10_epochs_diff_epsilon2.png')

# %%
n_10_e_vary3_i_75_acc = [
  [ 0.13333333333333333, 0.14, 0.12 ],
  [ 0.18666666666666668, 0.13333333333333333, 0.12666666666666668 ],
  [ 0.22666666666666666, 0.19333333333333333, 0.2866666666666667 ],
  [ 0.29333333333333333, 0.26, 0.25333333333333335 ],
  [ 0.29333333333333333, 0.32666666666666666, 0.30666666666666664 ],
  [ 0.19333333333333333, 0.26666666666666666, 0.22666666666666666 ],
  [ 0.22666666666666666, 0.21333333333333335, 0.22 ],
  [ 0.29333333333333333, 0.26, 0.22666666666666666 ],
  [ 0.28, 0.30666666666666664, 0.3 ],
  [ 0.12, 0.1, 0.10666666666666667 ],
  [ 0.19333333333333333, 0.17333333333333334, 0.18 ],
  [ 0.21333333333333335, 0.3, 0.26666666666666666 ],
  [ 0.19333333333333333, 0.15333333333333332, 0.16 ],
  [ 0.1, 0.10666666666666667, 0.10666666666666667 ],
  [ 0.26666666666666666, 0.23333333333333334, 0.25333333333333335 ],
  [ 0.22666666666666666, 0.23333333333333334, 0.25333333333333335 ],
  [ 0.23333333333333334, 0.20666666666666667, 0.25333333333333335 ],
  [ 0.3333333333333333, 0.28, 0.28 ],
  [ 0.16666666666666666, 0.16666666666666666, 0.12666666666666668 ],
  [ 0.23333333333333334, 0.26, 0.16 ],
  [ 0.29333333333333333, 0.30666666666666664, 0.32 ],
  [ 0.28, 0.3466666666666667, 0.31333333333333335 ],
  [ 0.18666666666666668, 0.14666666666666667, 0.18666666666666668 ],
  [ 0.14, 0.11333333333333333, 0.11333333333333333 ],
  [ 0.16, 0.22666666666666666, 0.21333333333333335 ]
]

n_10_e_vary3_i_75_acc_client1 = []
n_10_e_vary3_i_75_acc_client2 = []
n_10_e_vary3_i_75_acc_client3 = []

for i in n_10_e_vary3_i_75_acc:
    n_10_e_vary3_i_75_acc_client1.append(i[0]*100)
    n_10_e_vary3_i_75_acc_client2.append(i[1]*100)
    n_10_e_vary3_i_75_acc_client3.append(i[2]*100)

import matplotlib.pyplot as plt
import numpy as np

plt.plot(rounds, n_10_e_vary3_i_75_acc_client1, label='Client 1, E = 1')
plt.plot(rounds, n_10_e_vary3_i_75_acc_client2, label='Client 2, E = 10')
plt.plot(rounds, n_10_e_vary3_i_75_acc_client3, label='Client 3, E = 20')
plt.ylim(0, 100)
plt.legend()
plt.xlabel('Federated Learning Rounds')
plt.ylabel('Accuracy (%)')


plt.savefig('./results/clients_10_epochs_diff_epsilon3.png')

# %%
# Epochs:10, x-axis Epsilon[1, 4, 8, 15, 20, 25], params- round [5, 10, 15, 20]
n_10_e_20_acc = [
  [ 0.18666666666666668, 0.23333333333333334, 0.22 ],
  [ 0.6133333333333333, 0.64, 0.62 ],
  [ 0.6733333333333333, 0.7466666666666667, 0.72 ],
  [ 0.9533333333333334, 0.88, 0.9133333333333333 ],
  [ 0.9066666666666666, 0.8266666666666667, 0.9 ],
  [ 0.9266666666666666, 0.84, 0.9 ],
  [ 0.9533333333333334, 0.8866666666666667, 0.96 ],
  [ 0.9666666666666667, 0.9333333333333333, 0.96 ],
  [ 0.9733333333333334, 0.9533333333333334, 0.9666666666666667 ],
  [ 0.9666666666666667, 0.94, 0.9666666666666667 ],
  [ 0.96, 0.9666666666666667, 0.9866666666666667 ],
  [ 0.9666666666666667, 0.94, 0.98 ],
  [ 0.9666666666666667, 0.9466666666666667, 0.98 ],
  [ 0.9666666666666667, 0.94, 0.96 ],
  [ 0.9666666666666667, 0.9533333333333334, 0.98 ],
  [ 0.9666666666666667, 0.9466666666666667, 0.98 ],
  [ 0.9733333333333334, 0.9733333333333334, 0.9733333333333334 ],
  [ 0.9666666666666667, 0.9733333333333334, 0.9733333333333334 ],
  [ 0.9733333333333334, 0.9333333333333333, 0.9733333333333334 ],
  [ 0.9733333333333334, 0.96, 0.9733333333333334 ]
]

n_10_e_25_acc = [
  [ 0.13333333333333333, 0.15333333333333332, 0.13333333333333333 ],
  [ 0.7066666666666667, 0.72, 0.7333333333333333 ],
  [ 0.84, 0.78, 0.86 ],
  [ 0.9, 0.86, 0.86 ],
  [ 0.9466666666666667, 0.8466666666666667, 0.8933333333333333 ],
  [ 0.98, 0.92, 0.9533333333333334 ],
  [ 0.9666666666666667, 0.9133333333333333, 0.9133333333333333 ],
  [ 0.9733333333333334, 0.9466666666666667, 0.94 ],
  [ 0.9666666666666667, 0.9466666666666667, 0.9533333333333334 ],
  [ 0.9733333333333334, 0.9533333333333334, 0.9466666666666667 ],
  [ 0.96, 0.96, 0.9533333333333334 ],
  [ 0.9666666666666667, 0.96, 0.9466666666666667 ],
  [ 0.9733333333333334, 0.96, 0.94 ],
  [ 0.96, 0.9333333333333333, 0.9333333333333333 ],
  [ 0.9666666666666667, 0.9666666666666667, 0.9466666666666667 ],
  [ 0.9866666666666667, 0.98, 0.96 ],
  [ 0.9866666666666667, 0.9533333333333334, 0.9466666666666667 ],
  [ 0.9866666666666667, 0.9466666666666667, 0.9466666666666667 ],
  [ 0.98, 0.9733333333333334, 0.96 ],
  [ 0.9733333333333334, 0.9666666666666667, 0.96 ]
]

n_10_e_25_acc_client = [[], [], []]
n_10_e_20_acc_client = [[], [], []]

for i in n_10_e_25_acc:
    for j in range(3):
        n_10_e_25_acc_client[j].append(i[j]*100)

for i in n_10_e_20_acc:
    for j in range(3):
        n_10_e_20_acc_client[j].append(i[j]*100)

import matplotlib.pyplot as plt
import numpy as np

epsilon = [1, 4, 8, 15, 20, 25]

for i in range(3):
    plt.clf()
    rounds5 = []
    rounds10 = []
    rounds15 = []
    rounds20 = []

    rounds5.append(n_10_e_1_acc_client[i][4])
    rounds5.append(n_10_e_4_acc_client[i][4])
    rounds5.append(n_10_e_8_acc_client[i][4])
    rounds5.append(n_10_e_15_acc_client[i][4])
    rounds5.append(n_10_e_20_acc_client[i][4])
    rounds5.append(n_10_e_25_acc_client[i][4])

    rounds10.append(n_10_e_1_acc_client[i][9])
    rounds10.append(n_10_e_4_acc_client[i][9])
    rounds10.append(n_10_e_8_acc_client[i][9])
    rounds10.append(n_10_e_15_acc_client[i][9])
    rounds10.append(n_10_e_20_acc_client[i][9])
    rounds10.append(n_10_e_25_acc_client[i][9])

    rounds15.append(n_10_e_1_acc_client[i][14])
    rounds15.append(n_10_e_4_acc_client[i][14])
    rounds15.append(n_10_e_8_acc_client[i][14])
    rounds15.append(n_10_e_15_acc_client[i][14])
    rounds15.append(n_10_e_20_acc_client[i][14])
    rounds15.append(n_10_e_25_acc_client[i][14])

    rounds20.append(n_10_e_1_acc_client[i][19])
    rounds20.append(n_10_e_4_acc_client[i][19])
    rounds20.append(n_10_e_8_acc_client[i][19])
    rounds20.append(n_10_e_15_acc_client[i][19])
    rounds20.append(n_10_e_20_acc_client[i][19])
    rounds20.append(n_10_e_25_acc_client[i][19])

    plt.plot(epsilon, rounds5, label='Round 5')
    plt.plot(epsilon, rounds10, label='Round 10')
    plt.plot(epsilon, rounds15, label='Round 15')
    plt.plot(epsilon, rounds20, label='Round 20')
    plt.legend()

    plt.xlabel('Epsilon')
    plt.ylabel('Accuracy (%)')

    
    plt.savefig('./results/client{}_10_epochs_vary_rounds.png'.format(i+1))
